# %%
            sage: A = Matrix(([1, 1], [3, 1], [-1, -pi]))
            sage: b = vector((1000, 1500, -400)) * pi
            sage: c = vector((10, 5)) * pi
            sage: P = InteractiveLPProblemStandardForm(A, b, c)
            sage: P.run_simplex_method()
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1000 \, \pi \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{1} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{2}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1500 \, \pi \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3 x_{1} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{2}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} -400 \, \pi \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{1} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \pi x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 10 \, \pi x_{1} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 5 \, \pi x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# ...

# %%
        sage: from sage.numerical.interactive_simplex_method import \
        ....:       _latex_product
        sage: var("x, y")                                                               # needs sage.symbolic
        sage: print(_latex_product([-1, 3], [x, y]))
# Out:
# - \mspace{-6mu}&\mspace{-6mu} x \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 3 y

# %%
t = latex(-1); t
t.strip()
# Out:
# '-1'

# %% [markdown]
# $- \mspace{-6mu}&\mspace{-6mu} x \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 3 y$

# %%
            sage: from sage.rings.real_double import RDF
            sage: A = ([RDF(1), RDF(1)], [RDF(3), RDF(1)], [RDF(-1), RDF(-1)])
            sage: b = (RDF(1000), RDF(1500), RDF(-400))
            sage: c = (RDF(10), RDF(5))
            sage: P = InteractiveLPProblemStandardForm(A, b, c)
            sage: P.run_simplex_method()
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1000.0 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 1.0 x_{1} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 1.0 x_{2}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1500.0 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3.0 x_{1} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 1.0 x_{2}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} -400.0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 1.0 x_{1} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 1.0 x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 10.0 x_{1} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 5.0 x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# ...

# %%
𝑥3𝑥4𝑥5𝑧====1000𝜋1500𝜋−400𝜋0−−++1𝑥13𝑥1𝑥110𝜋𝑥1−−++1𝑥21𝑥2𝜋𝑥25𝜋𝑥2
The initial dictionary is infeasible, solving auxiliary problem.
𝑥3𝑥4𝑥5𝑤====1000𝜋1500𝜋−400𝜋0+++−𝑥0𝑥0𝑥01𝑥0−−+1𝑥13𝑥1𝑥1−−+1𝑥21𝑥2𝜋𝑥2
Entering: 𝑥0. Leaving: 𝑥5.
𝑥3𝑥4𝑥0𝑤====1400𝜋1900𝜋400𝜋−400𝜋+++−𝑥5𝑥5𝑥51𝑥5−−−+2𝑥14𝑥11𝑥1𝑥1−−−+(𝜋+1)𝑥2(𝜋+1)𝑥2𝜋𝑥2𝜋𝑥2
Entering: 𝑥1. Leaving: 𝑥0.
𝑥3𝑥4𝑥1𝑤====600𝜋300𝜋400𝜋0−−+1𝑥53𝑥5𝑥5++−−2𝑥04𝑥01𝑥01𝑥0++−(𝜋−1)𝑥2(3𝜋−1)𝑥2𝜋𝑥2
Back to the original problem.
𝑥3𝑥4𝑥1𝑧====600𝜋300𝜋400𝜋4000𝜋2−−++1𝑥53𝑥5𝑥510𝜋𝑥5++−+(𝜋−1)𝑥2(3𝜋−1)𝑥2𝜋𝑥2(5𝜋−10𝜋2)𝑥2
Entering: 𝑥5. Leaving: 𝑥4.
𝑥3𝑥5𝑥1𝑧====500𝜋100𝜋500𝜋5000𝜋2+−−−13𝑥413𝑥413𝑥4103𝜋𝑥4−+−+23𝑥2(𝜋−13)𝑥213𝑥2(5𝜋−10𝜋2+103𝜋(3𝜋−1))𝑥2
Entering: 𝑥2. Leaving: 𝑥3.
𝑥2𝑥5𝑥1𝑧====750𝜋100𝜋+250𝜋(3𝜋−1)250𝜋5000𝜋2+1250𝜋(3𝜋−6𝜋2+2𝜋(3𝜋−1))++−−12𝑥4(12𝜋−12)𝑥412𝑥4(56𝜋+5𝜋2−53𝜋(3𝜋−1))𝑥4−−+−32𝑥3(32𝜋−12)𝑥312𝑥3(152𝜋−15𝜋2+5𝜋(3𝜋−1))𝑥3
The optimal value: 5000𝜋2+1250𝜋(3𝜋−6𝜋2+2𝜋(3𝜋−1)). An optimal solution: (250𝜋,750𝜋).
